# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Relplot

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x = "total_bill", y = "tip", data = tips)

# %%
# 3 variables, 2 are numeric, 1 is categorical
sns.relplot(data = tips,
            x = "total_bill",
            y = "tip",
            hue = "smoker")

# %%
# 3 variables, all numeric
sns.relplot(data = tips,
            x = "total_bill",
            y = "tip",
            hue = "size")

# %%
# Change color for the 3rd variable
sns.relplot(data = tips,
            x = "total_bill",
            y = "tip",
            hue = "size",
            palette = "ch:r=-0.8,l=.95")

# %%
sns.relplot(data = tips,
            x = "total_bill",
            y = "tip",
            hue = "smoker",
            style = "time"
)

# %%
sns.relplot(data = tips,
            x = "total_bill",
            y = "tip",
            size = "size")

# %%
sns.relplot(data = tips,
            x = "total_bill",
            y = "tip",
            size = "size",
            sizes = (15, 200))

# %%
sns.scatterplot(data = tips,
                x = "total_bill",
                y = "tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))
df.head()
# Out:
#    time     value
# 0     0  0.402341
# 1     1  0.763178
# 2     2  0.153933
# 3     3  1.667781
# 4     4  2.253398

# %%
df.tail()
# Out:
#      time      value
# 495   495 -24.712510
# 496   496 -23.853197
# 497   497 -24.521851
# 498   498 -23.394542
# 499   499 -22.930660

# %%
sns.lineplot(data = df,
             x = "time",
             y = "value")
# Out:
# <AxesSubplot:xlabel='time', ylabel='value'>

# %%
# :)))
sns.scatterplot(data = df,
             x = "time",
             y = "value")
# Out:
# <AxesSubplot:xlabel='time', ylabel='value'>

# %%
df = pd.DataFrame(randn(500, 2).cumsum(axis = 0),
                  columns = ["time", "value"])

# %%
sns.lineplot(data = df,
             x = "time",
             y = "value",
             sort = False)
# Out:
# <AxesSubplot:xlabel='time', ylabel='value'>

# %%
sns.lineplot(data = df,
             x = "time",
             y = "value",
             sort = True)
# Out:
# <AxesSubplot:xlabel='time', ylabel='value'>

# %%
fmri = sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri.value_counts()
# Out:
# subject  timepoint  event  region    signal
# s0       0          cue    frontal    0.007766    1
# s5       7          stim   frontal    0.088225    1
#          4          cue    frontal    0.040826    1
#                            parietal   0.051541    1
#                     stim   frontal    0.186012    1
#                                                  ..
# s12      14         cue    frontal   -0.003318    1
#                            parietal  -0.021824    1
#                     stim   frontal   -0.039787    1
#                            parietal  -0.068297    1
# s9       18         stim   parietal  -0.103513    1
# Length: 1064, dtype: int64

# %%
fmri.loc[(fmri["timepoint"] == 5)]
# Out:
#     subject  timepoint event    region    signal
# 169     s12          5  stim  parietal  0.248138
# 184     s13          5  stim  parietal  0.252627
# 185      s6          5  stim  parietal  0.239175
# 186     s11          5  stim  parietal  0.194215
# 187     s10          5  stim  parietal  0.253871
# 188      s9          5  stim  parietal  0.381495
# 189      s8          5  stim  parietal  0.212855
# 190      s7          5  stim  parietal  0.177630
# 191      s5          5  stim  parietal  0.260057
# 192      s4          5  stim  parietal  0.460896
# 193      s3          5  stim  parietal  0.199188
# 194      s2          5  stim  parietal  0.209355
# 195      s1          5  stim  parietal  0.476055
# 196      s0          5  stim  parietal  0.175532
# 336      s1          5  stim   frontal  0.315860
# 337      s2          5  stim   frontal  0.149879
# 338      s3          5  stim   frontal  0.147985
# 339      s4          5  stim   frontal  0.455575
# ...

# %%
sns.lineplot(data = fmri,
             x = "timepoint",
             y = "signal")
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(data = fmri,
             x = "timepoint",
             y = "signal",
             ci = False)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(data = fmri,
             x = "timepoint",
             y = "signal",
             ci = "sd")
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(data = fmri,
             x = "timepoint",
             y = "signal",
             estimator = None)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(data = fmri,
             x = "timepoint",
             y = "signal",
             hue = "event")
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(data = fmri,
             x = "timepoint",
             y = "signal",
             hue = "region",
             style = "event")
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
dots = sns.load_dataset("dots")
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
dots["align"].value_counts()
# Out:
# sacc    454
# dots    394
# Name: align, dtype: int64

# %%
# Select rows that align == 'dots'
dots = dots.query("align == 'dots'")
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.lineplot(data = dots,
             x = "time",
             y = "firing_rate")
# Out:
# <AxesSubplot:xlabel='time', ylabel='firing_rate'>

# %%
df = pd.DataFrame(dict(time = pd.date_range(
    "2019-06-02", periods = 500),
    value = randn(500).cumsum()))
df.head()
# Out:
#         time     value
# 0 2019-06-02  1.506564
# 1 2019-06-03  2.315074
# 2 2019-06-04  2.361415
# 3 2019-06-05  2.419396
# 4 2019-06-06  2.048880

# %%
sns.lineplot(data = df,
             x = "time",
             y = "value")
# Out:
# <AxesSubplot:xlabel='time', ylabel='value'>

# %%
g = sns.lineplot(data = df,
                 x = "time",
                 y = "value")

g.figure.autofmt_xdate()

# %%
sns.relplot(data = tips,
            x = "total_bill",
            y = "tip",
            col = "time",
            kind = "scatter"
            )

# %%
sns.relplot(data = tips,
            x = "total_bill",
            y = "tip",
            hue = "smoker",
            col = "time",
            kind = "scatter")

# %%
sns.relplot(data = tips,
            x = "total_bill",
            y = "tip",
            row = "smoker",
            kind = "scatter")

# %%
sns.relplot(data = fmri,
            x = "timepoint",
            y = "signal",
            hue = "subject",
            col = "region",
            row = "event",
            kind = "line")

# %%
sns.relplot(data = fmri,
            x = "timepoint",
            y = "signal",
            hue = "subject",
            col = "region",
            row = "event",
            height = 10,
            kind = "line")

# %%
# Begin from here
sns.relplot(data = tips,
            x = "total_bill",
            y = "tip",
            hue = "smoker",
            col = "day",
            kind = "scatter")

# %%
sns.relplot(data = tips,
            x = "total_bill",
            y = "tip",
            hue = "smoker",
            col = "day",
            col_wrap = 3,
            kind = "scatter")

# %%
sns.relplot(data = tips,
            x = "total_bill",
            y = "tip",
            hue = "smoker",
            col = "day",
            col_wrap = 3,
            kind = "line")

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(data = tips,
            x = "day",
            y = "tip")

# %%
sns.catplot(data = tips,
            x = "day",
            y = "tip",
            jitter = False)

# %%
sns.catplot(data = tips,
            x = "day",
            y = "tip",
            kind = "swarm")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data = tips,
            x = "smoker",
            y = "tip",
            kind = "swarm")

# %%
sns.catplot(data = tips, kind = "swarm",
            x = "smoker",
            y = "tip",
            order = ["No", "Yes"])

# %%
sns.catplot(data = tips, kind = "box",
            x = "day",
            y = "total_bill")

# %%
diamonds = sns.load_dataset("diamonds")
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(data = diamonds, kind = "boxen",
            x = "color",
            y = "price")

# %%
sns.violinplot(data = tips,
            x = "total_bill",
            y = "day")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.violinplot(data = tips,
               x = "total_bill",
               y = "day",
               hue = "time",
               split = True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.catplot(data = titanic, kind = "bar",
            x = "sex",
            y = "survived",
            hue = "class"
            )

# %%
sns.catplot(data = titanic, kind = "bar",
            x = "sex",
            y = "survived")

# %%
sns.catplot(data = titanic, kind = "count",
            x = "deck")

# %%
sns.catplot(data = titanic, kind = "bar",
            x = "deck")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-2911f24c0516> in <module>
# ----> 1 sns.catplot(data = titanic, kind = "bar",
#       2             x = "deck")
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3787     p = _CategoricalPlotter()
#    3788     p.require_numeric = plotter_class.require_numeric
# ...
